# %%
from pyalex import Works, Authors, Sources, Institutions, Concepts, Publishers, Funders

# %%
import pyalex

pyalex.config.email = "quentin.glorieux@lkb.upmc.fr"

# %%
papers = Works().search_filter(title='a').get()
print(papers)

# %%
Works().search_filter(title="Temporally multiplexed storage of images ").get()
# Out:
# [{'id': 'https://openalex.org/W3098886231',
#   'doi': 'https://doi.org/10.1364/oe.20.012350',
#   'title': 'Temporally multiplexed storage of images in a gradient echo memory',
#   'display_name': 'Temporally multiplexed storage of images in a gradient echo memory',
#   'relevance_score': 614.8044,
#   'publication_year': 2012,
#   'publication_date': '2012-05-16',
#   'ids': {'openalex': 'https://openalex.org/W3098886231',
#    'doi': 'https://doi.org/10.1364/oe.20.012350',
#    'mag': '3098886231',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/22714222'},
#   'language': 'en',
#   'primary_location': {'is_oa': True,
#    'landing_page_url': 'https://doi.org/10.1364/oe.20.012350',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S178776955',
#     'display_name': 'Optics Express',
#     'issn_l': '1094-4087',
#     'issn': ['1094-4087'],
#     'is_oa': True,
#     'is_in_doaj': True,
#     'host_organization': 'https://openalex.org/P4310315679',
#     'host_organization_name': 'Optica Publishing Group',
#     'host_organization_lineage': ['https://openalex.org/P4310315679'],
#     'host_organization_lineage_names': ['Optica Publishing Group'],
#     'type': 'journal'},
#    'license': 'cc-by',
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   'type': 'article',
#   'type_crossref': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'gold',
#    'oa_url': 'https://doi.org/10.1364/oe.20.012350',
#    'any_repository_has_fulltext': True},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5024990264',
#      'display_name': 'Quentin Glorieux',
#      'orcid': 'https://orcid.org/0000-0003-0903-0233'},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Quentin Glorieux',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5025900147',
#      'display_name': 'J. B. Clark',
#      'orcid': None},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Jeremy B. Clark',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5021384595',
#      'display_name': 'Alberto M. Marino',
#      'orcid': 'https://orcid.org/0000-0001-5377-1122'},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Alberto M. Marino',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5067412578',
#      'display_name': 'Zhiqiang Zhou',
#      'orcid': 'https://orcid.org/0000-0001-6323-6756'},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Zhifan Zhou',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A5053748566',
#      'display_name': 'Paul D. Lett',
#      'orcid': 'https://orcid.org/0000-0002-7929-5547'},
#     'institutions': [],
#     'countries': [],
#     'is_corresponding': False,
#     'raw_author_name': 'Paul D. Lett',
#     'raw_affiliation_string': '',
#     'raw_affiliation_strings': []}],
#   'countries_distinct_count': 0,
#   'institutions_distinct_count': 0,
#   'corresponding_author_ids': [],
#   'corresponding_institution_ids': [],
#   'apc_list': {'value': 2270,
#    'currency': 'USD',
#    'value_usd': 2270,
#    'provenance': 'doaj'},
#   'apc_paid': {'value': 2270,
#    'currency': 'USD',
#    'value_usd': 2270,
#    'provenance': 'doaj'},
#   'has_fulltext': False,
#   'cited_by_count': 50,
#   'cited_by_percentile_year': {'min': 96.8, 'max': 96.9},
#   'biblio': {'volume': '20',
#    'issue': '11',
#    'first_page': '12350',
#    'last_page': '12350'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'keywords': [{'keyword': 'multiplexed storage', 'score': 0.4917},
#    {'keyword': 'memory', 'score': 0.4272},
#    {'keyword': 'echo', 'score': 0.3634},
#    {'keyword': 'images', 'score': 0.3246}],
#   'concepts': [{'id': 'https://openalex.org/C19275194',
#     'wikidata': 'https://www.wikidata.org/wiki/Q222903',
#     'display_name': 'Multiplexing',
#     'level': 2,
#     'score': 0.6963335},
#    {'id': 'https://openalex.org/C205372480',
#     'wikidata': 'https://www.wikidata.org/wiki/Q210521',
#     'display_name': 'Image resolution',
#     'level': 2,
#     'score': 0.63086545},
#    {'id': 'https://openalex.org/C120665830',
#     'wikidata': 'https://www.wikidata.org/wiki/Q14620',
#     'display_name': 'Optics',
#     'level': 1,
#     'score': 0.6156059},
#    {'id': 'https://openalex.org/C2779426996',
#     'wikidata': 'https://www.wikidata.org/wiki/Q18389128',
#     'display_name': 'Echo (communications protocol)',
#     'level': 2,
#     'score': 0.5480346},
#    {'id': 'https://openalex.org/C3019323268',
#     'wikidata': 'https://www.wikidata.org/wiki/Q48790829',
#     'display_name': 'Gradient echo',
#     'level': 3,
#     'score': 0.5353371},
#    {'id': 'https://openalex.org/C87519884',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2248059',
#     'display_name': 'Optical storage',
#     'level': 2,
#     'score': 0.52645403},
#    {'id': 'https://openalex.org/C194739806',
#     'wikidata': 'https://www.wikidata.org/wiki/Q66221',
#     'display_name': 'Computer data storage',
#     'level': 2,
#     'score': 0.5083839},
#    {'id': 'https://openalex.org/C69357855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q163214',
#     'display_name': 'Diffusion',
#     'level': 2,
#     'score': 0.482687},
#    {'id': 'https://openalex.org/C100921725',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1650811',
#     'display_name': 'Spatial frequency',
#     'level': 2,
#     'score': 0.42341614},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 0.33971703},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 0.33134007},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 0.3232159},
#    {'id': 'https://openalex.org/C76155785',
#     'wikidata': 'https://www.wikidata.org/wiki/Q418',
#     'display_name': 'Telecommunications',
#     'level': 1,
#     'score': 0.112137735},
#    {'id': 'https://openalex.org/C143409427',
#     'wikidata': 'https://www.wikidata.org/wiki/Q161238',
#     'display_name': 'Magnetic resonance imaging',
#     'level': 2,
#     'score': 0.078576595},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C31258907',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1301371',
#     'display_name': 'Computer network',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C97355855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11473',
#     'display_name': 'Thermodynamics',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C126838900',
#     'wikidata': 'https://www.wikidata.org/wiki/Q77604',
#     'display_name': 'Radiology',
#     'level': 1,
#     'score': 0.0},
#    {'id': 'https://openalex.org/C111919701',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#     'display_name': 'Operating system',
#     'level': 1,
#     'score': 0.0}],
#   'mesh': [{'descriptor_ui': 'D000465',
#     'descriptor_name': 'Algorithms',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': True},
#    {'descriptor_ui': 'D005740',
#     'descriptor_name': 'Gases',
#     'qualifier_ui': 'Q000737',
#     'qualifier_name': 'chemistry',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D007090',
#     'descriptor_name': 'Image Interpretation, Computer-Assisted',
#     'qualifier_ui': 'Q000379',
#     'qualifier_name': 'methods',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D016247',
#     'descriptor_name': 'Information Storage and Retrieval',
#     'qualifier_ui': 'Q000379',
#     'qualifier_name': 'methods',
#     'is_major_topic': True},
#    {'descriptor_ui': 'D008962',
#     'descriptor_name': 'Models, Theoretical',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': True},
#    {'descriptor_ui': 'D003198',
#     'descriptor_name': 'Computer Simulation',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D005740',
#     'descriptor_name': 'Gases',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D007090',
#     'descriptor_name': 'Image Interpretation, Computer-Assisted',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False},
#    {'descriptor_ui': 'D016247',
#     'descriptor_name': 'Information Storage and Retrieval',
#     'qualifier_ui': '',
#     'qualifier_name': None,
#     'is_major_topic': False}],
#   'locations_count': 4,
#   'locations': [{'is_oa': True,
#     'landing_page_url': 'https://doi.org/10.1364/oe.20.012350',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S178776955',
#      'display_name': 'Optics Express',
#      'issn_l': '1094-4087',
#      'issn': ['1094-4087'],
#      'is_oa': True,
#      'is_in_doaj': True,
#      'host_organization': 'https://openalex.org/P4310315679',
#      'host_organization_name': 'Optica Publishing Group',
#      'host_organization_lineage': ['https://openalex.org/P4310315679'],
#      'host_organization_lineage_names': ['Optica Publishing Group'],
#      'type': 'journal'},
#     'license': 'cc-by',
#     'version': 'publishedVersion',
#     'is_accepted': True,
#     'is_published': True},
#    {'is_oa': True,
#     'landing_page_url': 'http://arxiv.org/abs/1205.1495',
#     'pdf_url': 'http://arxiv.org/pdf/1205.1495',
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'host_organization_lineage': ['https://openalex.org/I205783295'],
#      'host_organization_lineage_names': ['Cornell University'],
#      'type': 'repository'},
#     'license': None,
#     'version': 'submittedVersion',
#     'is_accepted': False,
#     'is_published': False},
#    {'is_oa': True,
#     'landing_page_url': 'https://arxiv.org/abs/1205.1495',
#     'pdf_url': 'https://arxiv.org/pdf/1205.1495',
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': True,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'host_organization_lineage': ['https://openalex.org/I205783295'],
#      'host_organization_lineage_names': ['Cornell University'],
#      'type': 'repository'},
#     'license': None,
#     'version': 'publishedVersion',
#     'is_accepted': True,
#     'is_published': True},
#    {'is_oa': False,
#     'landing_page_url': 'https://pubmed.ncbi.nlm.nih.gov/22714222',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S4306525036',
#      'display_name': 'PubMed',
#      'issn_l': None,
#      'issn': None,
#      'is_oa': False,
#      'is_in_doaj': False,
#      'host_organization': 'https://openalex.org/I1299303238',
#      'host_organization_name': 'National Institutes of Health',
#      'host_organization_lineage': ['https://openalex.org/I1299303238'],
#      'host_organization_lineage_names': ['National Institutes of Health'],
#      'type': 'repository'},
#     'license': None,
#     'version': None,
#     'is_accepted': False,
#     'is_published': False}],
#   'best_oa_location': {'is_oa': True,
#    'landing_page_url': 'https://doi.org/10.1364/oe.20.012350',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S178776955',
#     'display_name': 'Optics Express',
#     'issn_l': '1094-4087',
#     'issn': ['1094-4087'],
#     'is_oa': True,
#     'is_in_doaj': True,
#     'host_organization': 'https://openalex.org/P4310315679',
#     'host_organization_name': 'Optica Publishing Group',
#     'host_organization_lineage': ['https://openalex.org/P4310315679'],
#     'host_organization_lineage_names': ['Optica Publishing Group'],
#     'type': 'journal'},
#    'license': 'cc-by',
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   'sustainable_development_goals': [{'id': 'https://metadata.un.org/sdg/7',
#     'display_name': 'Affordable and clean energy',
#     'score': 0.18}],
#   'grants': [],
#   'referenced_works_count': 28,
#   'referenced_works': ['https://openalex.org/W1490671191',
#    'https://openalex.org/W1963736202',
#    'https://openalex.org/W1966501758',
#    'https://openalex.org/W1979978884',
#    'https://openalex.org/W1985816534',
#    'https://openalex.org/W1992672788',
#    'https://openalex.org/W1998495845',
#    'https://openalex.org/W2001641833',
#    'https://openalex.org/W2004084841',
#    'https://openalex.org/W2005883583',
#    'https://openalex.org/W2006111387',
#    'https://openalex.org/W2019418813',
#    'https://openalex.org/W2020468818',
#    'https://openalex.org/W2031364271',
#    'https://openalex.org/W2037770501',
#    'https://openalex.org/W2045107268',
#    'https://openalex.org/W2054853777',
#    'https://openalex.org/W2056451059',
#    'https://openalex.org/W2057751654',
#    'https://openalex.org/W2065335654',
#    'https://openalex.org/W2083759876',
#    'https://openalex.org/W2086947442',
#    'https://openalex.org/W2132764286',
#    'https://openalex.org/W2160545453',
#    'https://openalex.org/W2170163127',
#    'https://openalex.org/W2596143204',
#    'https://openalex.org/W3101002145',
#    'https://openalex.org/W4292407905'],
#   'related_works': ['https://openalex.org/W2017987608',
#    'https://openalex.org/W3098886231',
#    'https://openalex.org/W2004296006',
#    'https://openalex.org/W2008327231',
#    'https://openalex.org/W2092079750',
#    'https://openalex.org/W4321516341',
#    'https://openalex.org/W1989017989',
#    'https://openalex.org/W2027791977',
#    'https://openalex.org/W2164794324',
#    'https://openalex.org/W4382141430'],
#   'ngrams_url': 'https://api.openalex.org/works/W3098886231/ngrams',
#   'abstract_inverted_index': {'We': [0, 19, 32],
#    'study': [1, 33],
#    'the': [2, 14, 26, 48, 57],
#    'storage': [3, 27, 67],
#    'and': [4, 36, 62, 76],
#    'retrieval': [5],
#    'of': [6, 28, 43, 53, 79],
#    'images': [7, 46],
#    'in': [8, 47],
#    'a': [9, 41, 69, 73],
#    'hot': [10],
#    'atomic': [11, 49, 54],
#    'vapor': [12],
#    'using': [13],
#    'gradient': [15],
#    'echo': [16],
#    'memory': [17],
#    'protocol.': [18],
#    'demonstrate': [20],
#    'that': [21],
#    'this': [22],
#    'technique': [23],
#    'allows': [24],
#    'for': [25],
#    'multiple': [29],
#    'spatial': [30, 35, 58],
#    'modes.': [31],
#    'both': [34],
#    'temporal': [37],
#    'multiplexing': [38],
#    'by': [39],
#    'storing': [40],
#    'sequence': [42],
#    'two': [44],
#    'different': [45],
#    'vapor.': [50],
#    'The': [51],
#    'effect': [52],
#    'diffusion': [55],
#    'on': [56],
#    'resolution': [59],
#    'is': [60, 82],
#    'discussed': [61],
#    'characterized': [63],
#    'experimentally.': [64],
#    'For': [65],
#    'short': [66],
#    'time': [68],
#    'normalized': [70],
#    'cross-correlation': [71],
#    'between': [72],
#    'retrieved': [74],
#    'image': [75],
#    'its': [77],
#    'input': [78],
#    '88': [80],
#    '%': [81],
#    'reported.': [83]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W3098886231',
#   'counts_by_year': [{'year': 2023, 'cited_by_count': 3},
#    {'year': 2022, 'cited_by_count': 2},
#    {'year': 2021, 'cited_by_count': 2},
#    {'year': 2020, 'cited_by_count': 2},
#    {'year': 2019, 'cited_by_count': 5},
#    {'year': 2018, 'cited_by_count': 2},
#    {'year': 2017, 'cited_by_count': 5},
#    {'year': 2016, 'cited_by_count': 3},
#    {'year': 2015, 'cited_by_count': 2},
#    {'year': 2014, 'cited_by_count': 6},
#    {'year': 2013, 'cited_by_count': 14},
#    {'year': 2012, 'cited_by_count': 4}],
#   'updated_date': '2023-11-15T05:14:46.321749',
#   'created_date': '2020-11-23'}]

# %%
def get_single_paper():

    doi = "https://doi.org/10.1103/PhysRevA.84.053826"
    works = Works()[doi]
    return works

paper = get_single_paper()

# %%
print({
    'title': paper['title'],
    'link': {
        'url' : paper['doi'],
        "authors": [
            {"name": entry["author"]["display_name"], "orcid": entry["author"]["orcid"]}
            for entry in paper["authorships"]
        ],
        'display' :paper["primary_location"]["source"]["display_name"]
            + " "
            + str(paper["biblio"]["volume"])
            + " "
            + str(paper["biblio"]["issue"])
            + " ("
            + str(paper["publication_year"])
            + ").",
        },
    "doi": paper["doi"],
    "is_oa": paper["open_access"]["is_oa"],
    "oa_url": paper["open_access"]["oa_url"],
    "publication_year": paper["publication_year"],
    "journal": paper["primary_location"]["source"]["display_name"],
    "biblio": paper["biblio"],
    })
# Out:
# {'title': 'Quantum correlations by four-wave mixing in an atomic vapor in a nonamplifying regime: Quantum beam splitter for photons', 'link': {'url': 'https://doi.org/10.1103/physreva.84.053826', 'authors': [{'name': 'Quentin Glorieux', 'orcid': 'https://orcid.org/0000-0003-0903-0233'}, {'name': 'Luca Guidoni', 'orcid': None}, {'name': 'S. Guibal', 'orcid': None}, {'name': 'Jean-Pierre Likforman', 'orcid': 'https://orcid.org/0000-0002-8879-7813'}, {'name': 'Thomas Coudreau', 'orcid': None}], 'display': 'Physical Review A 84 5 (2011).'}, 'doi': 'https://doi.org/10.1103/physreva.84.053826', 'is_oa': True, 'oa_url': 'https://arxiv.org/pdf/1111.4103', 'publication_year': 2011, 'journal': 'Physical Review A', 'biblio': {'volume': '84', 'issue': '5', 'first_page': None, 'last_page': None}}

# %%
import re

def get_openalex_id(input_identifier):
    authors = Authors()
    if "0-" in input_identifier:  # Assuming it's an ORCID number
       orcid_url = f"https://orcid.org/{input_identifier}"
       openalex_url = authors[orcid_url]['id']
    else:
        name_result = authors.search_filter(display_name=input_identifier).get()
        openalex_url = name_result[0]['id']
        
    pattern = re.compile(r'A(\d+)')
    match = pattern.search(openalex_url)
    if match:
        extracted_id = match.group(1)
        return 'A' + extracted_id
    else:
        return

# %% [markdown]
# ## Fetch

# %%
import pandas as pd

pager = (
    Works()
    .filter(author={"id": "A5024990264"})
    .filter(has_doi=True, primary_location={"source": {"has_issn": True}})
    .select(
        [
            "id",
            "doi",
            "title",
            "publication_year",
            "ids",
            "type",
            "type_crossref",
            "open_access",
            "primary_location",
            "authorships",
            "biblio",
            "concepts",
        ]
    )
    .sort(publication_year="desc")
    .paginate(per_page=100)
)
list = []
for page in pager:
    list = list + page
df0 = pd.DataFrame(list)
df = df0

# %% [markdown]
# ## Code to export the publication list

# %%
import json


# Define a function to extract author information
def extract_author_info(row):
    match = re.search(r'physrev(.+?)(\d+)', row["doi"])
    if match:
        if match.group(1)[0] not in ('l', 'r', 'x') : 
            journal_abbreviation = match.group(1)[0].capitalize()
        else: 
            journal_abbreviation = ""
    else:
        journal_abbreviation = ""
    return {
        "title": row["title"],
        "authors": [
            {"name": entry["author"]["display_name"], "orcid": entry["author"]["orcid"]}
            for entry in row["authorships"]
        ],
        "link": {
            "url": row["doi"],
            "display": row["primary_location"]["source"]["display_name"]
            + " "
            + str(row["biblio"]["volume"])
            + " "
            + str(row["biblio"]["issue"])
            + " ("
            + str(row["publication_year"])
            + ").",
        },
        "orcid": [entry["author"]["orcid"] for entry in row["authorships"]],
        "doi": row["doi"],
        "is_oa": row["open_access"]["is_oa"],
        "oa_url": row["open_access"]["oa_url"],
        "publication_year": row["publication_year"],
        "journal": row["primary_location"]["source"]["display_name"],
        "journal_abbreviation": journal_abbreviation,
        "biblio": row["biblio"],
    }


# Apply the function to each row and create a list of dictionaries
author_info_list = df.apply(extract_author_info, axis=1).tolist()

# Convert the list of dictionaries to a JSON string
json_string = json.dumps(author_info_list, indent=2)

# Save the JSON string to a file
with open("../_data/openalex_list.json", "w") as file:
    file.write(json_string)

# %% [markdown]
# ## Tests

# %%
# IDs
expanded_df = pd.json_normalize(df['ids'])
result_df = pd.concat([df, expanded_df], axis=1)
result_df = result_df.drop(['ids', 'pmid', 'pmcid'], axis=1)

#Location
expanded_df = pd.json_normalize(df['primary_location'])
result_df = pd.concat([df, expanded_df], axis=1)
result_df = result_df.drop(['primary_location', 'license', 'version'], axis=1)
